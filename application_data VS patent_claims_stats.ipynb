# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# df = pd.read_csv("./patent.tsv", sep="\t", nrows = 500 )
application_df = pd.read_csv("csv_patent_2019/application_data.csv")
# Out:
# C:\Users\gongl\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0,1,3,4,5,6,8,9,10,12,13,14,16,17,18,19,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
application_df.head()
# Out:
#   application_number filing_date application_invention_type  \
# 0            2000161         NaN                    Utility
# 1            2022946         NaN                    Utility
# 2            2032617         NaN                    Utility
# 3            2045760  1948-08-23                        NaN
# 4            2048602         NaN                        NaN
#
#   examiner_full_name examiner_art_unit uspc_class uspc_subclass  \
# 0                NaN               NaN        NaN           NaN
# 1                NaN               NaN        NaN           NaN
# 2                NaN               NaN        NaN           NaN
# 3                NaN               NaN        NaN           NaN
# 4                NaN               NaN        NaN           NaN
#
#    confirm_number atty_docket_number  \
# 0          1014.0                NaN
# 1          1141.0                NaN
# 2          1195.0                NaN
# 3          1267.0                NaN
# ...

# %%
application_cleaned = application_df.drop(columns=['confirm_number', 'wipo_pub_number', 'wipo_pub_date'])
application_cleaned.head()
# Out:
#   application_number filing_date application_invention_type  \
# 0            2000161         NaN                    Utility
# 1            2022946         NaN                    Utility
# 2            2032617         NaN                    Utility
# 3            2045760  1948-08-23                        NaN
# 4            2048602         NaN                        NaN
#
#   examiner_full_name examiner_art_unit uspc_class uspc_subclass  \
# 0                NaN               NaN        NaN           NaN
# 1                NaN               NaN        NaN           NaN
# 2                NaN               NaN        NaN           NaN
# 3                NaN               NaN        NaN           NaN
# 4                NaN               NaN        NaN           NaN
#
#   atty_docket_number                                   appl_status_desc  \
# 0                NaN                                                NaN
# ...

# %%
application_cleaned.sort_values(["patent_issue_date"], ascending = False).head()
# Out:
#         application_number filing_date application_invention_type  \
# 8610530           15748314  2018-01-29                    Utility
# 9039493           16227984  2018-12-20                    Utility
# 8743553           15889157  2018-02-05                    Utility
# 8743552           15889156  2018-02-05                    Utility
# 8621287           15759128  2018-03-09                    Utility
#
#            examiner_full_name examiner_art_unit uspc_class uspc_subclass  \
# 8610530             SHEN, BIN              1653        435        404000
# 9039493      VOSTAL, ONDREJ C              2458        709        238000
# 8743553      SIDDIQUI, KASHIF              2415        370        252000
# 8743552          PHAM, QUAN L              2696        348        241000
# 8621287  CRANE, LAUREN ASHLEY              3754          4        679000
#
#         atty_docket_number                                   appl_status_desc  \
# ...

# %%
application_cleaned

usa_ufo_df = application_cleaned.loc[application_cleaned["patent_number"] == "5010660", :]
usa_ufo_df
# Out:
#        application_number filing_date application_invention_type  \
# 972302            7293956  1989-01-06                    Utility
#
#        examiner_full_name examiner_art_unit uspc_class uspc_subclass  \
# 972302   BENNETT, HENRY A              3404        034        092000
#
#        atty_docket_number appl_status_desc appl_status_date  \
# 972302       89LABC0103JD    Patented Case       1991-02-27
#
#                       file_location file_location_date earliest_pgpub_number  \
# 972302  FILE REPOSITORY (FRANCONIA)         2018-07-11                   NaN
#
#        earliest_pgpub_date patent_number patent_issue_date  \
# 972302                 NaN       5010660        1991-04-30
#
#                                   invention_title small_entity_indicator  \
# 972302  METHOD AND APPARATUS FOR DRYING GLASSWARE                  SMALL
#
#        aia_first_to_file
# 972302             False

# %%
patent_claims_stats_df = pd.read_csv("csv_patent_2019/patent_claims_stats.csv")
# Out:
# C:\Users\gongl\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
patent_claims_stats_df = patent_claims_stats_df.rename(columns={"pat_no": "patent_number"})
patent_claims_stats_df
# Out:
#          patent_number  claim_no  word_ct  char_ct  or_ct  sf_ct  cns_ct  \
# 0              3930271         4       53      299      0      0       0
# 1              3930271         2       31      194      0      0       0
# 2              3930271         3       66      452      0      0       0
# 3              3930271         1       53      347      0      0       0
# 4              3930272         2       15       88      0      0       0
# ...                ...       ...      ...      ...    ...    ...     ...
# 75930659       RE45254        31       26      181      1      0       0
# 75930660       RE45254        30       65      408      2      0       0
# 75930661       RE45254         7       49      336      2      0       0
# 75930662       RE45254        22      201     1262      2      0       0
# 75930663       RE45254        16       41      242      0      0       0
#
#           ind_flg     appl_id
# 0               1         NaN
# ...

# %%
inner_merged_total = pd.merge(application_df, patent_claims_stats_df, on=["patent_number"])
inner_merged_total
# Out:
#         application_number filing_date application_invention_type  \
# 0                  5010660         NaN                   Re-Issue
# 1                  5010660         NaN                   Re-Issue
# 2                  5010660         NaN                   Re-Issue
# 3                  5010660         NaN                   Re-Issue
# 4                  5010660         NaN                   Re-Issue
# ...                    ...         ...                        ...
# 1260460           29409384  2011-12-22                   Re-Issue
# 1260461           29409392  2011-12-22                   Re-Issue
# 1260462           29414353  2012-02-28                   Re-Issue
# 1260463           29415275  2012-03-08                   Re-Issue
# 1260464           29439750  2012-12-14                   Re-Issue
#
#             examiner_full_name examiner_art_unit uspc_class uspc_subclass  \
# 0                          NaN              2401        220         27100
# ...

# %%
inner_merged_total.columns
# Out:
# Index(['application_number', 'filing_date', 'application_invention_type',
#        'examiner_full_name', 'examiner_art_unit', 'uspc_class',
#        'uspc_subclass', 'confirm_number', 'atty_docket_number',
#        'appl_status_desc', 'appl_status_date', 'file_location',
#        'file_location_date', 'earliest_pgpub_number', 'earliest_pgpub_date',
#        'wipo_pub_number', 'wipo_pub_date', 'patent_number',
#        'patent_issue_date', 'invention_title', 'small_entity_indicator',
#        'aia_first_to_file', 'claim_no', 'word_ct', 'char_ct', 'or_ct', 'sf_ct',
#        'cns_ct', 'ind_flg', 'appl_id'],
#       dtype='object')

# %%
inner_merged_total

patented_df = inner_merged_total.loc[inner_merged_total["appl_status_desc"] == "Patented Case", :]
patented_df
# Out:
#         application_number filing_date application_invention_type  \
# 0                  5010660         NaN                   Re-Issue
# 1                  5010660         NaN                   Re-Issue
# 2                  5010660         NaN                   Re-Issue
# 3                  5010660         NaN                   Re-Issue
# 4                  5010660         NaN                   Re-Issue
# ...                    ...         ...                        ...
# 1260460           29409384  2011-12-22                   Re-Issue
# 1260461           29409392  2011-12-22                   Re-Issue
# 1260462           29414353  2012-02-28                   Re-Issue
# 1260463           29415275  2012-03-08                   Re-Issue
# 1260464           29439750  2012-12-14                   Re-Issue
#
#             examiner_full_name examiner_art_unit uspc_class uspc_subclass  \
# 0                          NaN              2401        220         27100
# ...
