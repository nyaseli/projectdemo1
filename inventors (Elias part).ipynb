# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("all_inventors.csv")
# Out:
# C:\Users\nyase\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#   application_number inventor_name_first inventor_name_middle  \
# 0            5692088                TROY                   E.
# 1            5692088               JAMES                   E.
# 2            5692179              PIETRO
# 3            5692179             FRANCIS                   J.
# 4            5692179             CHESTER                   J.
#
#   inventor_name_last  inventor_rank inventor_city_name inventor_region_code  \
# 0              PLUNK              1            Bedford                   MA
# 1             HOPSON              2          Wellesley                   MA
# 2          VENTRESCA              1          Littleton                   MA
# 3             O'HARA              2            Bedford                   MA
# 4               HUNT              3            Melrose                   MA
#
#   inventor_country_code
# 0                    US
# 1                    US
# 2                    US
# 3                    US
# 4                    US

# %%
countries = df["inventor_country_code"].value_counts()
countries
# Out:
# US    14141292
# JP     4530027
# DE     1624815
# KR     1236629
# TW      784345
#         ...
# VC           1
# TY           1
# FX           1
# \            1
# JS           1
# Name: inventor_country_code, Length: 283, dtype: int64

# %%
countries.plot(kind = "pie")
# Out:
# <AxesSubplot:ylabel='inventor_country_code'>

# %%
states_df = df.loc[df["inventor_country_code"] == "US"]

# %%
states = states_df["inventor_region_code"].value_counts()
states
# Out:
# CA     3534022
# NY      906520
# TX      886656
# MA      806486
# NJ      587521
#         ...
# ES           1
# NT           1
# ILA          1
# DT           1
# CAQ          1
# Name: inventor_region_code, Length: 233, dtype: int64

# %%
states.plot(kind = "pie")
# Out:
# <AxesSubplot:ylabel='inventor_region_code'>

# %%
Michael = states_df.loc[states_df["inventor_name_first"]== "Michael"]

# %%
Lee = Michael.loc[Michael["inventor_name_last"]== "Lee"]

# %%
Lee
# Out:
#          application_number inventor_name_first inventor_name_middle  \
# 8225762            09839291             Michael                   H.
# 8373725            09894858             Michael                  NaN
# 8373770            09894862             Michael                  NaN
# 8446112            09918301             Michael                  NaN
# 8496945            09935378             Michael                   G.
# ...                     ...                 ...                  ...
# 28704317           16152487             Michael           Chun-chieh
# 28885480           16224004             Michael                  NaN
# 28888050           16225059             Michael                James
# 29038707           16284219             Michael                   H.
# 29213690           16477133             Michael                  NaN
#
#          inventor_name_last  inventor_rank inventor_city_name  \
# 8225762                 Lee              1           San Jose
# ...

# %%
df.describe(include = "all")
# Out:
#        application_number inventor_name_first inventor_name_middle  \
# count            29233628            29221029             12058982
# unique           11561769              538832               169697
# top              10424310             Michael
# freq                  435              383638               978925
# mean                  NaN                 NaN                  NaN
# std                   NaN                 NaN                  NaN
# min                   NaN                 NaN                  NaN
# 25%                   NaN                 NaN                  NaN
# 50%                   NaN                 NaN                  NaN
# 75%                   NaN                 NaN                  NaN
# max                   NaN                 NaN                  NaN
#
#        inventor_name_last  inventor_rank inventor_city_name  \
# count            29231538   2.923363e+07           29134861
# ...
